# %% [markdown]
# <a href="https://colab.research.google.com/github/alessandrotavazzi/collaboration_swisscom/blob/main/notebooks/data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
# </div>
#
# <div class="markdown-google-sans">
#   <h2>Explore the Gemini API</h2>
#   <p>The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#   </p>
#   <strong>How to get started</strong>
#     <ol>
#       <li>Go to <a href="https://aistudio.google.com/">Google AI Studio</a> and log in with your Google account.</li>
#       <li><a href="https://aistudio.google.com/app/apikey">Create an API key</a>.</li>
#       <li>Use a quickstart for <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Prompting.ipynb">Python</a>, or call the REST API using <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb">curl</a>.</li>
#       </ol>
#   <strong>Explore use cases</strong>
#     <ul>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Market_a_Jet_Backpack.ipynb">Create a marketing campaign</a></li>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Audio.ipynb">Analyze audio recordings</a></li>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/System_instructions.ipynb">Use System instructions in chat</a></li>
#     </ul>
#   <p>To learn more, check out the <a href="https://github.com/google-gemini/cookbook">Gemini cookbook</a> or visit the <a href="https://ai.google.dev/docs/">Gemini API documentation</a>.
#   </p>
# </div>

# %% [markdown]
# # New Section

# %% [markdown]
# <msg desc="Text shown above a link to https://www.youtube.com/watch?v=V7RXyqFUR98 which highlights some helpful features in Colab">Colab now has AI features powered by <a href="https://gemini.google.com">Gemini</a>. The video below provides information on how to use these features, whether you're new to Python, or a seasoned veteran.</msg>
#
# <center>
#   <a href="https://www.youtube.com/watch?v=V7RXyqFUR98" target="_blank">
#   <img alt='Thumbnail for a video showing 3 AI-powered Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) or [Colab Features You May Have Missed](https://www.youtube.com/watch?v=rNgswRZ2C1Y) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-eb250fa3eac1> in <cell line: 1>()
# ----> 1 seconds_in_a_week = 7 * seconds_in_a_day
#       2 seconds_in_a_week
#
# NameError: name 'seconds_in_a_day' is not defined

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.
#
# For example, if you find yourself waiting for **pandas** code to finish running and want to go faster, you can switch to a GPU Runtime and use libraries like [RAPIDS cuDF](https://rapids.ai/cudf-pandas) that provide zero-code-change acceleration.

# %% [markdown]
# To learn more about accelerating pandas on Colab, see the [10 minute guide](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_colab_demo.ipynb) or
#  [US stock market data analysis demo](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_stocks_demo.ipynb).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb).

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colab](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning Crash Course
#
# <div>
#
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Intro to RAPIDS cuDF to accelerate pandas](https://nvda.ws/rapids-cudf)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %% [markdown]
# # Data Analysis: Investment trends AI technologies Silicon Valley

# %%
from IPython.display import HTML

html_code = """
<div id="animatedText" style="font-size: 24px; font-weight: bold;">
  Let us start doing data analysis!
</div>

<script>
  let colors = [ 'green', 'blue', 'purple'];
  let index = 0;

  function changeColor() {
    document.getElementById('animatedText').style.color = colors[index];
    index = (index + 1) % colors.length;
  }

  setInterval(changeColor, 500);  // Change color every 500ms
</script>
"""

HTML(html_code)
# Out:
# <div id="animatedText" style="font-size: 24px; font-weight: bold;">
#   Let us start doing data analysis!
# </div>
#
# <script>
#   let colors = [ 'green', 'blue', 'purple'];
#   let index = 0;
#
#   function changeColor() {
#     document.getElementById('animatedText').style.color = colors[index];
#     index = (index + 1) % colors.length;
#   }
#
#   setInterval(changeColor, 500);  // Change color every 500ms
# </script>

# %% [markdown]
# The aim of this notebook is to evaluate industry trends regarding AI and Cybersecurity in the Silicon Valley. \\
#
# # The dataset
#
# The dataset is taken from CB Insights, a business analytics platform and global database, providing market intelligence on private companies and investor activities. It serves professionals in private equity, venture capital, investment banking, angel investing, and consulting, offering insights into high-growth private companies. \\
#
# # Content
#
# 1) Data Cleaning
#
# 2) Data Exploration
#
# 3) Data Visualization

# %%
## First import the necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# 1. Importing the data

# %%
data = pd.read_csv("CBI Search Results.csv")
# To display the top 5 rows
data.head(5)
# Out:
#      Companies              URL  \
# 0   Calypso AI    calypsoai.com
# 1      Cranium       cranium.ai
# 2    WitnessAI       witness.ai
# 3   Protect AI    protectai.com
# 4  HiddenLayer  hiddenlayer.com
#
#                                          Description  \
# 0  Calypso AI specializes in providing a secure, ...
# 1  Cranium focuses on AI security within the cybe...
# 2  WitnessAI focuses on AI security and governanc...
# 3  Protect AI develops cybersecurity solutions fo...
# 4  HiddenLayer specializes in providing security ...
#
#                     Business Model                      Industry  \
# 0                   B2B, B2G, SaaS             Security Software
# 1                        B2B, SaaS  Internet Software & Services
# 2                        B2B, SaaS  Internet Software & Services
# 3                        B2B, SaaS  Internet Software & Services
# 4  B2B, B2G, Fee-for-service, SaaS                   IT Services
#
# ...

# %%
data.tail(5)
# To display the botton 5 rows
# Out:
#                        Companies               URL  \
# 772                 ClusterPower   clusterpower.ro
# 773  Concerto Software & Systems  concertosoft.com
# 774                Kris Infotech           kris.sg
# 775           Sublime Consulting        sublime.se
# 776              Quantum Thought     quthought.com
#
#                                            Description  \
# 772  ClusterPower is a provider of digital solution...
# 773  Concerto Software & Systems specializes in pay...
# 774  Kris Infotech is a technology consulting and t...
# 775  Sublime Consulting is a digital agency special...
# 776  Quantum Thought is a quantum application devel...
#
#                   Business Model                      Industry  \
# 772  B2B, B2G, SaaS, Usage-based          Servers & Mainframes
# 773   B2B, Fee-for-service, SaaS  Internet Software & Services
# 774         B2B, Fee-for-service                   IT Services
# 775         B2B, Fee-for-service                   IT Services
# ...

# %%
data.describe()
# Out:
#        Mosaic (Overall)  Total Funding (M)  Latest Funding Amount (M)  \
# count        432.000000         297.000000                 249.000000
# mean         436.877315          30.597374                  16.783414
# std          178.892484          87.062821                  46.767524
# min           43.000000           0.020000                   0.010000
# 25%          285.500000           1.250000                   0.540000
# 50%          437.500000           6.000000                   4.000000
# 75%          555.000000          20.350000                  15.000000
# max          905.000000         829.630000                 487.780000
#
#        Total Headcount  Founded Year  Your Collections
# count       560.000000    651.000000               0.0
# mean        200.680357   2015.649770               NaN
# std        1663.553105     10.744598               NaN
# min           0.000000   1897.000000               NaN
# 25%           4.000000   2015.000000               NaN
# ...

# %% [markdown]
# 2. Dropping irrelevant columns

# %%
data = data.drop(['URL', 'Description', 'Business Model', 'Team Tag', 'Your Collections'], axis=1)
data.head(5)
# Out:
#      Companies                      Industry             Sub-Industry  \
# 0   Calypso AI             Security Software                      NaN
# 1      Cranium  Internet Software & Services    Monitoring & Security
# 2    WitnessAI  Internet Software & Services    Monitoring & Security
# 3   Protect AI  Internet Software & Services    Monitoring & Security
# 4  HiddenLayer                   IT Services  Data Storage & Security
#
#                                   Expert Collections  \
# 0  Artificial Intelligence, Cybersecurity, Genera...
# 1             Artificial Intelligence, Cybersecurity
# 2             Artificial Intelligence, Cybersecurity
# 3  AI 100, Artificial Intelligence, Cybersecurity...
# 4  AI 100, Artificial Intelligence, Cybersecurity...
#
#                          Markets  Mosaic (Overall) Commercial Maturity  \
# 0  AI security (Enterprise Tech)             552.0        3: Deploying
# 1  AI security (Enterprise Tech)             761.0        3: Deploying
# ...

# %% [markdown]
# 3. Checking the types of data

# %%
data.dtypes
# Out:
# Companies                       object
# Industry                        object
# Sub-Industry                    object
# Expert Collections              object
# Markets                         object
# Mosaic (Overall)               float64
# Commercial Maturity             object
# IPO Probability                 object
# M&A Probability                 object
# Country                         object
# Total Funding (M)              float64
# All Investors                   object
# Latest Funding Amount (M)      float64
# Latest Funding Round            object
# Latest Funding Date             object
# Total Headcount                float64
# 12 Month Headcount Change %     object
# Company Status                  object
# Founded Year                   float64
# dtype: object

# %%
data.select_dtypes(include=np.number)
# Out:
#      Mosaic (Overall)  Total Funding (M)  Latest Funding Amount (M)  \
# 0               552.0              38.20                      23.00
# 1               761.0              51.65                      19.65
# 2               726.0              27.50                      27.50
# 3               697.0             108.50                      60.00
# 4               839.0              56.00                      50.00
# ..                ...                ...                        ...
# 772             222.0                NaN                        NaN
# 773               NaN                NaN                        NaN
# 774               NaN                NaN                        NaN
# 775               NaN                NaN                        NaN
# 776               NaN                NaN                        NaN
#
#      Total Headcount  Founded Year
# 0                NaN        2018.0
# 1               43.0        2022.0
# 2               18.0        2023.0
# ...

# %% [markdown]
# 4. Dropping out duplicate raws

# %%
duplicate_rows_df = data[data.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 19)

# %%
data.count()
# Out:
# Companies                      777
# Industry                       765
# Sub-Industry                   616
# Expert Collections             430
# Markets                        154
# Mosaic (Overall)               432
# Commercial Maturity            381
# IPO Probability                620
# M&A Probability                620
# Country                        777
# Total Funding (M)              297
# All Investors                  529
# Latest Funding Amount (M)      249
# Latest Funding Round           435
# Latest Funding Date            435
# Total Headcount                560
# 12 Month Headcount Change %    777
# Company Status                 777
# Founded Year                   651
# dtype: int64

# %% [markdown]
# 5. Dropping the missing or null values.

# %%
print(data.isnull().sum())
# Out:
# Companies                        0
# Industry                        12
# Sub-Industry                   161
# Expert Collections             347
# Markets                        623
# Mosaic (Overall)               345
# Commercial Maturity            396
# IPO Probability                157
# M&A Probability                157
# Country                          0
# Total Funding (M)              480
# All Investors                  248
# Latest Funding Amount (M)      528
# Latest Funding Round           342
# Latest Funding Date            342
# Total Headcount                217
# 12 Month Headcount Change %      0
# Company Status                   0
# Founded Year                   126
# dtype: int64

# %%
data.isnull()
# Out:
#      Companies  Industry  Sub-Industry  Expert Collections  Markets  \
# 0        False     False          True               False    False
# 1        False     False         False               False    False
# 2        False     False         False               False    False
# 3        False     False         False               False    False
# 4        False     False         False               False    False
# ..         ...       ...           ...                 ...      ...
# 772      False     False          True                True     True
# 773      False     False         False                True     True
# 774      False     False         False                True     True
# 775      False     False          True                True     True
# 776      False     False         False                True     True
#
#      Mosaic (Overall)  Commercial Maturity  IPO Probability  M&A Probability  \
# ...

# %%
data.shape
# Out:
# (777, 19)

# %%
data = data.dropna()    # Dropping the missing values.
data.count()
# Out:
# Companies                      65
# Industry                       65
# Sub-Industry                   65
# Expert Collections             65
# Markets                        65
# Mosaic (Overall)               65
# Commercial Maturity            65
# IPO Probability                65
# M&A Probability                65
# Country                        65
# Total Funding (M)              65
# All Investors                  65
# Latest Funding Amount (M)      65
# Latest Funding Round           65
# Latest Funding Date            65
# Total Headcount                65
# 12 Month Headcount Change %    65
# Company Status                 65
# Founded Year                   65
# dtype: int64

# %%
print(data.isnull().sum())   # After dropping the values
# Out:
# Companies                      0
# Industry                       0
# Sub-Industry                   0
# Expert Collections             0
# Markets                        0
# Mosaic (Overall)               0
# Commercial Maturity            0
# IPO Probability                0
# M&A Probability                0
# Country                        0
# Total Funding (M)              0
# All Investors                  0
# Latest Funding Amount (M)      0
# Latest Funding Round           0
# Latest Funding Date            0
# Total Headcount                0
# 12 Month Headcount Change %    0
# Company Status                 0
# Founded Year                   0
# dtype: int64

# %% [markdown]
# Now we have removed all the rows which contain the Null or N/A values (Cylinders and Horsepower (HP)).

# %% [markdown]
# Modification of the dataset: we want to remove the '%', as they are not useful for further computations.

# %%
def myfunc(x):
  for element in x:
    new = element.replace('%', '')
    x= x.replace(element,new)
  return x

# %%
data['12 Month Headcount Change %']= data[['12 Month Headcount Change %']].apply(myfunc)
data['IPO Probability']=data[['IPO Probability']].apply(myfunc)
data['M&A Probability']=data[['M&A Probability']].apply(myfunc)

# %%
data
# Out:
#        Companies                      Industry  \
# 1        Cranium  Internet Software & Services
# 2      WitnessAI  Internet Software & Services
# 4    HiddenLayer                   IT Services
# 5       DeepKeep  Internet Software & Services
# 6     Chainguard  Internet Software & Services
# ..           ...                           ...
# 632      Kern AI  Internet Software & Services
# 656         VOLT  Internet Software & Services
# 665       Saidot  Internet Software & Services
# 667    ammune.ai  Internet Software & Services
# 701       Scylla  Internet Software & Services
#
#                                           Sub-Industry  \
# 1                                Monitoring & Security
# 2                                Monitoring & Security
# 4                              Data Storage & Security
# 5                                Monitoring & Security
# 6                             Supply Chain & Logistics
# ..                                                 ...
# ...

# %% [markdown]
# # Data Exploration

# %% [markdown]
# 1. Detecting Outliers

# %%
# for total funding
sns.boxplot(x=data['Total Funding (M)'])
plt.title('Distribution Total Funding')
# Out:
# Text(0.5, 1.0, 'Distribution Total Funding')

# %%
data
# Out:
#        Companies                      Industry  \
# 1        Cranium  Internet Software & Services
# 2      WitnessAI  Internet Software & Services
# 4    HiddenLayer                   IT Services
# 5       DeepKeep  Internet Software & Services
# 6     Chainguard  Internet Software & Services
# ..           ...                           ...
# 632      Kern AI  Internet Software & Services
# 656         VOLT  Internet Software & Services
# 665       Saidot  Internet Software & Services
# 667    ammune.ai  Internet Software & Services
# 701       Scylla  Internet Software & Services
#
#                                           Sub-Industry  \
# 1                                Monitoring & Security
# 2                                Monitoring & Security
# 4                              Data Storage & Security
# 5                                Monitoring & Security
# 6                             Supply Chain & Logistics
# ..                                                 ...
# ...

# %%
# for Mosaic (Overall)
sns.boxplot(x=data['Mosaic (Overall)'])

plt.title('Distribution Mosaic (Overall)')
# Out:
# Text(0.5, 1.0, 'Distribution Mosaic (Overall)')

# %%
# for IPO Probability

sns.boxplot(x=data['IPO Probability'],whis=(0, 100))

plt.xticks((0.4,25))

plt.title('Distribution IPO Probability')

# Display the plot
plt.show()

# %%
# for M&A Probability
sns.boxplot(x=data['M&A Probability'],whis=(0, 100))

plt.xticks((0.4,25))

plt.title('Distribution M&A Probability')

# Display the plot
plt.show()

# %%
# Latest Funding Amount (M)
sns.boxplot(x=data['Latest Funding Amount (M)'])

plt.title('Distribution Latest Funding Amount (M)')
# Out:
# Text(0.5, 1.0, 'Distribution Latest Funding Amount (M)')

# %%
# Latest Funding Round	Month Headcount Change
sns.boxplot(x=data['12 Month Headcount Change %'],whis=(0, 100))

plt.xticks((0.4,25))
plt.title('Distribution 12 Month Headcount Change %')

# Display the plot
plt.show()

# %% [markdown]
# 2. Frequency numeric variables

# %%
# Total Funding (M)

x = data['Total Funding (M)']

plt.xlabel('Total Funding (M)')
plt.title('Distribution of Total Funding (M)')

plt.hist(x)
plt.show()

# %%
# Mosaic (Overall)

x = data['Mosaic (Overall)']

plt.xlabel('Mosaic (Overall)')
plt.title('Distribution of Mosaic (Overall)')

plt.hist(x)
plt.show()

# %%
# IPO Probability

x = new_list

plt.xticks(np.arange(0, 26, 2))  # Creates ticks from 0 to 10 with step size of 1

plt.xlabel('IPO Probability (%)')
plt.title('Distribution of IPO Probabilities')

plt.hist(x)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-ecd2bb3cc0ef> in <cell line: 3>()
#       1 # IPO Probability
#       2
# ----> 3 x = new_list
#       4
#       5 plt.xticks(np.arange(0, 26, 2))  # Creates ticks from 0 to 10 with step size of 1
#
# NameError: name 'new_list' is not defined

# %%
plt.hist(new_list)
plt.xticks(np.arange(0, 31, 2))  # Creates ticks from 0 to 10 with step size of 1
plt.xlabel('M&A Probability (%)')
plt.title('Distribution of M&A Probabilities')
plt.show()

# %%
# Latest Funding Amount (M)

x = data['Latest Funding Amount (M)']

plt.xlabel('Latest Funding Amount (M)')
plt.title('Distribution of Latest Funding Amount (M)')

plt.hist(x)
plt.show()

# %%
# 12 Month Headcount Change %

x = new_list

plt.xticks(np.arange(0, 900, 90))  # Creates ticks from 0 to 10 with step size of 1

plt.xlabel('12 Month Headcount Change %')
plt.title('Distribution of 12 Month Headcount Change %')

plt.hist(x)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-82a2ba05eeae> in <cell line: 3>()
#       1 # 12 Month Headcount Change %
#       2
# ----> 3 x = new_list
#       4
#       5 plt.xticks(np.arange(0, 900, 90))  # Creates ticks from 0 to 10 with step size of 1
#
# NameError: name 'new_list' is not defined

# %%
data

# %% [markdown]
# # Analyses of correlations

# %% [markdown]
# General correlations among the variables

# %%
# Select the columns for correlation analysis
columns_for_correlation = [
    'Mosaic (Overall)',
    'Latest Funding Amount (M)',
    'Total Headcount',
    '12 Month Headcount Change %',
    'Founded Year'
]

# Create correlation matrix
correlation_matrix = data[columns_for_correlation].corr()

# Create a heatmap visualization
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix,
            annot=True,  # Show correlation values
            cmap='coolwarm',  # Color scheme (red for positive, blue for negative)
            vmin=-1, vmax=1,  # Set correlation range
            center=0,  # Center the colormap at 0
            fmt='.2f',  # Round to 2 decimal places
            square=True)  # Make cells square

plt.title('Correlation Matrix of Key Metrics', pad=20)
plt.tight_layout()
plt.show()

# Print detailed correlation analysis
print("\nDetailed Correlations:")
for col1 in columns_for_correlation:
    for col2 in columns_for_correlation:
        if col1 < col2:  # Avoid printing duplicate correlations
            corr = correlation_matrix.loc[col1, col2]
            print(f"{col1} vs {col2}: {corr:.3f}")
# Out:
# Detailed Correlations:
# Mosaic (Overall) vs Total Headcount: 0.367
# Latest Funding Amount (M) vs Mosaic (Overall): 0.429
# Latest Funding Amount (M) vs Total Headcount: 0.339
# 12 Month Headcount Change % vs Mosaic (Overall): 0.151
# 12 Month Headcount Change % vs Latest Funding Amount (M): -0.053
# 12 Month Headcount Change % vs Total Headcount: -0.062
# 12 Month Headcount Change % vs Founded Year: 0.320
# Founded Year vs Mosaic (Overall): 0.069
# Founded Year vs Latest Funding Amount (M): -0.140
# Founded Year vs Total Headcount: -0.338

# %% [markdown]
# Correlation between the founded year and the Total Funding for each company.

# %%
# Create scatter plot
plt.figure(figsize=(12, 8))

# Get unique companies for different colors
companies = data['Companies'].unique()
colors = plt.cm.tab20(np.linspace(0, 1, len(companies)))  # Create color palette

# Plot each company's data with different colors
for company, color in zip(companies, colors):
    company_data = data[data['Companies'] == company]
    plt.scatter(company_data['Founded Year'],
               company_data['Total Funding (M)'],
               label=company,
               color=color,
               alpha=0.7,  # Some transparency
               s=100)      # Size of points

# Customize the plot
plt.title('Company Funding Over Time', fontsize=14, pad=20)
plt.xlabel('Founded Year', fontsize=12)
plt.ylabel('Total Funding (M$)', fontsize=12)

# Add legend with two columns
plt.legend(bbox_to_anchor=(1.05, 1),
          loc='upper left',
          borderaxespad=0.,
          fontsize=10,
          ncol=2)  # Set number of columns to 2

# Adjust layout to prevent legend cutoff
plt.tight_layout()

# Show grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

# Prepare data for clustering
features_for_clustering = ['Total Funding (M)', 'Mosaic (Overall)', 'Total Headcount']
X = data[features_for_clustering].copy()

# Handle missing values
X = X.fillna(X.mean())

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=features_for_clustering)

# Perform K-means clustering
n_clusters = 3
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
data['Cluster'] = kmeans.fit_predict(X_scaled)

# Visualize clusters
plt.figure(figsize=(12, 8))
sns.scatterplot(data=data,
                x='Total Funding (M)',
                y='Total Headcount',
                hue='Cluster',
                size='Mosaic (Overall)',
                sizes=(50, 400),
                palette='deep')

plt.title('Company Clusters based on Funding, Headcount, and Mosaic Score')
plt.xlabel('Total Funding (M$)')
plt.ylabel('Total Headcount')
plt.legend(title='Cluster')
plt.show()

# Analyze cluster characteristics
print("\nCluster Characteristics:")
print(data.groupby('Cluster')[features_for_clustering].mean())
# Out:
# Cluster Characteristics:
#          Total Funding (M)  Mosaic (Overall)  Total Headcount
# Cluster
# 0                34.346066        625.737705        61.426230
# 1               829.630000        839.000000       285.000000
# 2               355.523333        872.000000      1366.333333

# %% [markdown]
# # Data Visualization

# %% [markdown]
# This section contains the following part:
#
# 1) For each industry: the number of companies \\
# 2) For each subindustry: the number of companies  \\
# 3) For each market: the number of companies  \\
# 4) For each market: the average IPO probability  \\
# 5) For each industry: average IPO probability \\
# 6) For each sub-industry: average IPO probability  \\
# 7) Average M&A Probability by Market \\
# 8) Funding Amount (M) for each market \\
# 9) Distribution Working Force among Industries

# %% [markdown]
# 1) For each industry: the number of companies

# %%
# 12 Month Headcount Change %

words = list(set(list(data['Industry'])))

numbers = []

for element in words:
  numbers.append(len(data[data['Industry']==element]))

# Create the bar plot
plt.figure(figsize=(14, 6))
plt.bar(words, numbers)

# Customize the plot
plt.title('Distribution of companies by industries')
plt.xlabel('Industries')
plt.ylabel('Numbers')

# Add value labels on top of each bar
for i, v in enumerate(numbers):
    plt.text(i, v, str(v), ha='center', va='bottom')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# 2) For each subindustry: the number of companies

# %%
# 12 Month Headcount Change %

words = list(set(list(data['Sub-Industry'])))

numbers = []

for element in words:
  numbers.append(len(data[data['Sub-Industry']==element]))

# Create the bar plot
plt.figure(figsize=(30, 6))
plt.bar(words, numbers)

plt.xticks(fontsize=8)

# Customize the plot
plt.title('Distribution of companies by sub-industry')
plt.xlabel('Sub-Industry')
plt.ylabel('Numbers')

# Add value labels on top of each bar
for i, v in enumerate(numbers):
    plt.text(i, v, str(v), ha='center', va='bottom')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# 3) For each market: the number of companies

# %%
import re
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize

def summarize_text(text, num_sentences=3):
    # Download necessary NLTK data (run once)
    import nltk
    nltk.download('punkt')
    nltk.download('stopwords')

    # Tokenize the text into sentences
    sentences = sent_tokenize(text)

    # Tokenize words and remove stopwords
    stop_words = set(stopwords.words('english'))
    words = word_tokenize(text.lower())
    words = [word for word in words if word.isalnum() and word not in stop_words]

    # Calculate word frequencies
    word_freq = Counter(words)

    # Calculate sentence scores based on word frequencies
    sentence_scores = {}
    for i, sentence in enumerate(sentences):
        for word in word_tokenize(sentence.lower()):
            if word in word_freq:
                if i in sentence_scores:
                    sentence_scores[i] += word_freq[word]
                else:
                    sentence_scores[i] = word_freq[word]

    # Get the top n sentences with the highest scores
    top_sentences = sorted(sentence_scores, key=sentence_scores.get, reverse=True)[:num_sentences]

    # Combine the top sentences in their original order
    summary = ' '.join([sentences[i] for i in sorted(top_sentences)])

    return summary

# %%
mywords = list(set(list(data['Markets'])))

words = []

for word in mywords:
  words.append(summarize_text(word, num_sentences=1))

print(mywords)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %%
def create_chart(mylist):
    # Filter data for the markets in mylist
    filtered_data = data[data['Markets'].isin(mylist)]

    # Get unique markets and their counts
    market_counts = filtered_data['Markets'].value_counts()
    mywords = market_counts.index.tolist()
    numbers = market_counts.values.tolist()

    # Create figure and axis
    fig, ax = plt.subplots(figsize=(10, 10))

    # Create horizontal bars
    y_pos = np.arange(len(mywords))
    bars = ax.barh(y_pos, numbers, align='center')

    # Color each bar differently
    colors = plt.cm.viridis(np.linspace(0, 1, len(numbers)))
    for bar, color in zip(bars, colors):
        bar.set_color(color)

    # Summarize market names
    words = [summarize_text(word, num_sentences=1) for word in mywords]

    # Customize the plot
    ax.set_yticks(y_pos)
    ax.set_yticklabels(words)
    ax.invert_yaxis()  # Words read top-to-bottom
    ax.set_xlabel('Number of Occurrences')
    ax.set_title('Horizontal Bar Chart of Markets and Their Occurrences')

    # Set x-axis limits to include all data points
    ax.set_xlim(0, max(numbers) * 1.1)

    # Add value labels on the bars
    for i, v in enumerate(numbers):
        ax.text(v, i, str(v), va='center', ha='left', fontweight='bold', fontsize=10, color='black')

    # Remove y-axis line
    ax.spines['left'].set_visible(False)

    # Create legend
    legend_elements = [plt.Rectangle((0,0),1,1, fc=color, label=f'{word} ({num})')
                       for color, word, num in zip(colors, mywords, numbers)]
    ax.legend(handles=legend_elements, loc='center left', bbox_to_anchor=(1, 0.5),
              title="Legend", title_fontsize=12)

    # Adjust layout and display the plot
    plt.tight_layout()
    plt.show()

# %%
ai_ml = [
    'AI development platforms (Enterprise Tech)',
    'Small language models (SLMs) tools & development (Enterprise Tech)',
    'Generative AI — text-to-code & data querying (Enterprise Tech)',
    'Generative AI — large language model (LLM) developers (Enterprise Tech)',
    'Large language model (LLM) application development (Enterprise Tech)',
    'Model validation & monitoring (Enterprise Tech)',
    'AI security (Enterprise Tech)',
    'LLM benchmarking & model routing (Enterprise Tech)',
    'Machine learning security (MLSec) (Enterprise Tech)',
    'General enterprise AI agents & copilots (Enterprise Tech)',
    'Security operations center (SOC) AI agents & copilots (Enterprise Tech)',
    'Autonomous agents & digital coworkers (Enterprise Tech)',
    'Synthetic training data — media (Enterprise Tech)'
]

cybersecurity = [
    'Unified threat management (UTM) (Enterprise Tech)',
    'Security awareness training (Enterprise Tech)',
    'Endpoint detection & response (EDR) (Enterprise Tech)',
    'Extended detection & response (XDR) (Enterprise Tech)',
    'Identity & access management (IAM) (Enterprise Tech)',
    'Email security (Enterprise Tech)',
    'Secure web gateway (SWG) (Enterprise Tech)',
    'Data security posture management (DSPM) (Enterprise Tech)',
    'Data access governance (Enterprise Tech)',
    'Security information & event management (SIEM) (Enterprise Tech)',
    'Security orchestration automation & response (SOAR) (Enterprise Tech)',
    'Threat intelligence platforms (Enterprise Tech)',
    'User & entity behavior analytics (UEBA) (Enterprise Tech)',
    'Physical security (Enterprise Tech)',
    'Interactive application security testing (IAST) (Enterprise Tech)',
    'Breach & attack simulation (BAS) (Enterprise Tech)',
    'Vulnerability management (Enterprise Tech)',
    'Bug bounty platforms (Enterprise Tech)',
    'Penetration testing (Enterprise Tech)',
    'Attack surface management (Enterprise Tech)',
    'Threat deception platforms (Enterprise Tech)',
    'Web application & API protection (WAAP) (Enterprise Tech)',
    'Cloud-native application protection platforms (CNAPP) (Enterprise Tech)',
    'Code review (Enterprise Tech)',
    'Digital brand protection (Enterprise Tech)',
    'Container & kubernetes security (Enterprise Tech)',
    'Software supply chain security tools (Enterprise Tech)',
    'Database security (Enterprise Tech)',
    'Smart home security (Enterprise Tech)'
]

data_management = [
    'Data governance & privacy (Enterprise Tech)',
    'Data quality monitoring (Enterprise Tech)',
    'Algorithmic auditing & risk management (Enterprise Tech)',
    'Model validation & monitoring (Enterprise Tech)'
]

identity_management = [
    'Biometric identity (Enterprise Tech)',
    'Identity & access management (IAM) (Enterprise Tech)'
]

military_defense = [
    'Signals intelligence (SIGINT) (Industrials)',
    'Battle management systems (BMS) (Industrials)'
]

specialized_security = [
    'AI-powered video security monitoring (Enterprise Tech)',
    'Security operations center (SOC) AI agents & copilots (Enterprise Tech)'
]

# %%
create_chart(ai_ml)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %%
create_chart(ai_ml)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %%
create_chart(cybersecurity)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %%
create_chart(data_management)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <ipython-input-63-eac2e34af1a4>:49: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
create_chart(identity_management)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
create_chart(military_defense)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
create_chart(specialized_security)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <ipython-input-63-eac2e34af1a4>:49: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# 4) For each market: the average IPO probability

# %%
# Clean market names by removing parentheses and standardizing technology categories
def clean_market_name(market):
    # Remove everything in parentheses and strip whitespace
    cleaned = market.split('(')[0].strip()
    # If it contains 'Tech' or 'Technology', just return 'Technology'
    if 'Tech' in cleaned or 'Technology' in cleaned:
        return 'Technology'
    return cleaned

# Create cleaned market names and calculate probabilities
market_probs = {}
for market in set(data['Markets']):
    clean_name = clean_market_name(market)
    mydata = data[data['Markets']==market]
    mylist = [float(x.rstrip('%'))/100 for x in list(mydata['IPO Probability'])]

    # If market already exists, take average of all values for that market
    if clean_name in market_probs:
        existing_values = market_probs[clean_name] * len(market_probs)  # Multiply by count to get sum
        market_probs[clean_name] = (existing_values + sum(mylist)) / (len(market_probs) + len(mylist))
    else:
        market_probs[clean_name] = sum(mylist)/len(mylist)

# Convert dictionary to lists for plotting
markets = list(market_probs.keys())
probs = list(market_probs.values())

# Visualize in a horizontal bar plot
plt.figure(figsize=(10, 8))
plt.barh(markets, probs, color='skyblue')
plt.title('Average IPO Probability by Market')
plt.xlabel('Average IPO Probability')
plt.ylabel('Markets')
plt.tight_layout()
plt.show()

# %% [markdown]
# 5) For each industry: average IPO probability

# %%
# Create cleaned industry names and calculate probabilities
industry_probs = {}
for industry in set(data['Industry']):
    mydata = data[data['Industry']==industry]
    mylist = [float(x.rstrip('%')) for x in list(mydata['IPO Probability'])]
    # Calculate average probability for each industry
    industry_probs[industry] = sum(mylist)/len(mylist)

# Convert dictionary to lists for plotting
industries = list(industry_probs.keys())
probs = list(industry_probs.values())

# Visualize in a horizontal bar plot
plt.figure(figsize=(10, 8))
plt.barh(industries, probs, color='skyblue')
plt.title('Average IPO Probability by Industry')
plt.xlabel('Average IPO Probability')
plt.ylabel('Industry')
plt.tight_layout()
plt.show()

# %% [markdown]
# 6) For each sub-industry: average IPO probability

# %%
# Create cleaned industry names and calculate probabilities
industry_probs = {}
for industry in set(data['Sub-Industry']):
    mydata = data[data['Sub-Industry']==industry]
    mylist = [float(x.rstrip('%')) for x in list(mydata['IPO Probability'])]
    # Calculate average probability for each industry
    industry_probs[industry] = sum(mylist)

# Convert dictionary to lists for plotting
industries = list(industry_probs.keys())
probs = list(industry_probs.values())

# Visualize in a horizontal bar plot
plt.figure(figsize=(10, 8))
plt.barh(industries, probs, color='skyblue')
plt.title('Average IPO Probability by Sub-Industry')
plt.xlabel('Average IPO Probability')
plt.ylabel('Sub-Industry')
plt.tight_layout()
plt.show()

# %% [markdown]
# 7) Average M&A Probability by Market

# %%
# Clean market names by removing parentheses and standardizing technology categories
def clean_market_name(market):
    # Remove everything in parentheses and strip whitespace
    cleaned = market.split('(')[0].strip()
    # If it contains 'Tech' or 'Technology', just return 'Technology'
    if 'Tech' in cleaned or 'Technology' in cleaned:
        return 'Technology'
    return cleaned

# Create cleaned market names and calculate probabilities
market_probs = {}
for market in set(data['Markets']):
    clean_name = clean_market_name(market)
    mydata = data[data['Markets']==market]
    mylist = [float(x.rstrip('%'))/100 for x in list(mydata['M&A Probability'])]

    # If market already exists, take average of all values for that market
    if clean_name in market_probs:
        existing_values = market_probs[clean_name] * len(market_probs)  # Multiply by count to get sum
        market_probs[clean_name] = (existing_values + sum(mylist)) / (len(market_probs) + len(mylist))
    else:
        market_probs[clean_name] = sum(mylist)/len(mylist)

# Convert dictionary to lists for plotting
markets = list(market_probs.keys())
probs = list(market_probs.values())

# Visualize in a horizontal bar plot
plt.figure(figsize=(10, 8))
plt.barh(markets, probs, color='skyblue')
plt.title('Average M&A Probability by Market')
plt.xlabel('Average M&A Probability')
plt.ylabel('Markets')
plt.tight_layout()
plt.show()

# %%
# Create cleaned industry names and calculate probabilities
industry_probs = {}
for industry in set(data['Industry']):
    mydata = data[data['Industry']==industry]
    mylist = [float(x.rstrip('%')) for x in list(mydata['M&A Probability'])]
    # Calculate average probability for each industry
    industry_probs[industry] = sum(mylist)/len(mylist)

# Convert dictionary to lists for plotting
industries = list(industry_probs.keys())
probs = list(industry_probs.values())

# Visualize in a horizontal bar plot
plt.figure(figsize=(10, 8))
plt.barh(industries, probs, color='skyblue')
plt.title('Average M&A Probability by Industry')
plt.xlabel('Average M&A Probability')
plt.ylabel('Industry')
plt.tight_layout()
plt.show()

# %%
# Create cleaned industry names and calculate probabilities
industry_probs = {}
for industry in set(data['Sub-Industry']):
    mydata = data[data['Sub-Industry']==industry]
    mylist = [float(x.rstrip('%')) for x in list(mydata['M&A Probability'])]
    # Calculate average probability for each industry
    industry_probs[industry] = sum(mylist)

# Convert dictionary to lists for plotting
industries = list(industry_probs.keys())
probs = list(industry_probs.values())

# Visualize in a horizontal bar plot
plt.figure(figsize=(10, 8))
plt.barh(industries, probs, color='skyblue')
plt.title('Average M&A Probability by Sub-Industry')
plt.xlabel('Average M&A Probability')
plt.ylabel('Sub-Industry')
plt.tight_layout()
plt.show()

# %%
data
# Out:
#        Companies                      Industry  \
# 1        Cranium  Internet Software & Services
# 2      WitnessAI  Internet Software & Services
# 4    HiddenLayer                   IT Services
# 5       DeepKeep  Internet Software & Services
# 6     Chainguard  Internet Software & Services
# ..           ...                           ...
# 632      Kern AI  Internet Software & Services
# 656         VOLT  Internet Software & Services
# 665       Saidot  Internet Software & Services
# 667    ammune.ai  Internet Software & Services
# 701       Scylla  Internet Software & Services
#
#                                           Sub-Industry  \
# 1                                Monitoring & Security
# 2                                Monitoring & Security
# 4                              Data Storage & Security
# 5                                Monitoring & Security
# 6                             Supply Chain & Logistics
# ..                                                 ...
# ...

# %% [markdown]
# 8) Funding Amount (M) for each market

# %%
# Clean market names by removing parentheses and standardizing technology categories
def clean_market_name(market):
    # Remove everything in parentheses and strip whitespace
    cleaned = market.split('(')[0].strip()
    # If it contains 'Tech' or 'Technology', just return 'Technology'
    if 'Tech' in cleaned or 'Technology' in cleaned:
        return 'Technology'
    return cleaned

# Create cleaned market names and calculate probabilities
market_probs = {}
for market in set(data['Markets']):
    clean_name = clean_market_name(market)
    mydata = data[data['Markets']==market]
    mylist = list(mydata['Total Funding (M)'])

    # If market already exists, take average of all values for that market
    if clean_name in market_probs:
        existing_values = market_probs[clean_name] * len(market_probs)  # Multiply by count to get sum
        market_probs[clean_name] = (existing_values + sum(mylist)) / (len(market_probs) + len(mylist))
    else:
        market_probs[clean_name] = sum(mylist)/len(mylist)

# Convert dictionary to lists for plotting
markets = list(market_probs.keys())
probs = list(market_probs.values())

# Visualize in a horizontal bar plot
plt.figure(figsize=(10, 8))
plt.barh(markets, probs, color='skyblue')
plt.title('Total Funding (M) by Market')
plt.xlabel('Total Funding (M)')
plt.ylabel('Markets')
plt.tight_layout()
plt.show()

# %%
# Create cleaned industry names and calculate probabilities
industry_probs = {}
for industry in set(data['Industry']):
    mydata = data[data['Industry']==industry]
    mylist =  list(mydata['Total Funding (M)'])
    # Calculate average probability for each industry
    industry_probs[industry] = sum(mylist)/len(mylist)

# Convert dictionary to lists for plotting
industries = list(industry_probs.keys())
probs = list(industry_probs.values())

# Visualize in a horizontal bar plot
plt.figure(figsize=(10, 8))
plt.barh(industries, probs, color='skyblue')
plt.title('Total Funding (M) by Industry')
plt.xlabel('Total Funding (M)')
plt.ylabel('Industry')
plt.tight_layout()
plt.show()

# %%
# Create cleaned industry names and calculate probabilities
industry_probs = {}
for industry in set(data['Sub-Industry']):
    mydata = data[data['Sub-Industry']==industry]
    mylist = list(mydata['Total Funding (M)'])
    # Calculate average probability for each industry
    industry_probs[industry] = sum(mylist)

# Convert dictionary to lists for plotting
industries = list(industry_probs.keys())
probs = list(industry_probs.values())

# Visualize in a horizontal bar plot
plt.figure(figsize=(10, 8))
plt.barh(industries, probs, color='skyblue')
plt.title('Total Funding (M) by Sub-Industry')
plt.xlabel('Total Funding (M)')
plt.ylabel('Sub-Industry')
plt.tight_layout()
plt.show()

# %% [markdown]
# 9) Distribution Working Force among Industries

# %%
# Calculate total headcount first
total_headcount = data['Total Headcount'].sum()

# Add new column with percentage calculations
data['Percent Working Force'] = (100*data['Total Headcount'] / total_headcount)

# %%
# Clean market names by removing parentheses and standardizing technology categories
def clean_market_name(market):
    # Remove everything in parentheses and strip whitespace
    cleaned = market.split('(')[0].strip()
    # If it contains 'Tech' or 'Technology', just return 'Technology'
    if 'Tech' in cleaned or 'Technology' in cleaned:
        return 'Technology'
    return cleaned

# Create cleaned market names and calculate probabilities
market_probs = {}
for market in set(data['Markets']):
    clean_name = clean_market_name(market)
    mydata = data[data['Markets']==market]
    mylist = list(mydata['Percent Working Force'])

    # If market already exists, take average of all values for that market
    if clean_name in market_probs:
        existing_values = market_probs[clean_name] * len(market_probs)  # Multiply by count to get sum
        market_probs[clean_name] = (existing_values + sum(mylist)) / (len(market_probs) + len(mylist))
    else:
        market_probs[clean_name] = sum(mylist)/len(mylist)

# Convert dictionary to lists for plotting
markets = list(market_probs.keys())
probs = list(market_probs.values())

# Visualize in a horizontal bar plot
plt.figure(figsize=(10, 8))
plt.barh(markets, probs, color='skyblue')
plt.title('Percent Working Force by Market')
plt.xlabel('Percent Working Force')
plt.ylabel('Markets')
plt.tight_layout()
plt.show()

# %%
# Create cleaned industry names and calculate probabilities
industry_probs = {}
for industry in set(data['Industry']):
    mydata = data[data['Industry']==industry]
    mylist =  list(mydata['Percent Working Force'])
    # Calculate average probability for each industry
    industry_probs[industry] = sum(mylist)

# Convert dictionary to lists for plotting
industries = list(industry_probs.keys())
probs = list(industry_probs.values())

# Visualize in a horizontal bar plot
plt.figure(figsize=(10, 8))
plt.barh(industries, probs, color='skyblue')
plt.title('Percent Working Force by Industry')
plt.xlabel('Percent Working Force')
plt.ylabel('Industry')
plt.tight_layout()
plt.show()

# %%
# Create cleaned industry names and calculate probabilities
industry_probs = {}
for industry in set(data['Sub-Industry']):
    mydata = data[data['Sub-Industry']==industry]
    mylist = list(mydata['Percent Working Force'])
    # Calculate average probability for each industry
    industry_probs[industry] = sum(mylist)

# Convert dictionary to lists for plotting
industries = list(industry_probs.keys())
probs = list(industry_probs.values())

# Visualize in a horizontal bar plot
plt.figure(figsize=(10, 8))
plt.barh(industries, probs, color='skyblue')
plt.title('Percent Working Force by Sub-Industry')
plt.xlabel('Percent Working Force')
plt.ylabel('Sub-Industry')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Time-based analysis
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 12))

# 1. Funding trends by founding year
# Ensure valid data in 'Founded Year' and fill missing values
data['Founded Year'] = data['Founded Year'].fillna(0).astype(int)
yearly_funding = data.groupby('Founded Year')['Total Funding (M)'].agg(['mean', 'count'])

# Plot average funding by founding year
ax1.bar(yearly_funding.index, yearly_funding['mean'], alpha=0.7)
ax1.set_title('Average Funding by Founding Year', pad=20)
ax1.set_xlabel('Founded Year')
ax1.set_ylabel('Average Total Funding (M$)')

# Add company count as text above each bar
for i, count in enumerate(yearly_funding['count']):
    ax1.text(yearly_funding.index[i], yearly_funding['mean'][i],
             f'n={count}', ha='center', va='bottom')

# 2. Growth metrics by market
market_metrics = data.groupby('Markets').agg({
    'Total Headcount': 'mean',
    '12 Month Headcount Change %': 'mean',
    'Mosaic (Overall)': 'mean'
}).sort_values('Total Headcount', ascending=False)

market_metrics.plot(kind='bar', ax=ax2)
ax2.set_title('Market Comparison: Headcount, Growth, and Mosaic Score', pad=20)
ax2.set_xlabel('Markets')
ax2.legend()
ax2.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# Detailed statistical analysis
print("\nMarket Statistics:")
market_stats = data.groupby('Markets').agg({
    'Total Funding (M)': ['mean', 'median', 'count'],
    'Total Headcount': ['mean', 'median'],
    '12 Month Headcount Change %': ['mean', 'median'],
    'Mosaic (Overall)': ['mean', 'median']
}).round(2)

print(market_stats)

# Create new figure for heatmap
plt.figure(figsize=(12, 6))

# Check if 'Founded Year' has enough valid data and cut accordingly
if data['Founded Year'].nunique() > 4:
    growth_analysis = pd.crosstab(
        pd.qcut(data['Founded Year'], q=4, labels=['Early', 'Growth', 'Mature', 'Established']),
        pd.qcut(data['Total Funding (M)'], q=4, labels=['Low', 'Medium', 'High', 'Very High'])
    )

    sns.heatmap(growth_analysis, annot=True, fmt='d', cmap='YlOrRd')
    plt.title('Company Distribution: Age vs Funding')
    plt.xlabel('Funding Level')
    plt.ylabel('Company Age Stage')
    plt.tight_layout()
    plt.show()
else:
    print("Not enough unique values in 'Founded Year' for quantile-based grouping.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-33dcfee966c5> in <cell line: 20>()
#      19 # Add company count as text above each bar
# ...

# %%
# Time-based analysis
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 12))

# 1. Funding trends by founding year
yearly_funding = data.groupby('Founded Year')['Total Funding (M)'].agg(['mean', 'count'])
ax1.bar(yearly_funding.index, yearly_funding['mean'], alpha=0.7)
ax1.set_title('Average Funding by Founding Year', pad=20)
ax1.set_xlabel('Founded Year')
ax1.set_ylabel('Average Total Funding (M$)')

# Add company count as text above each bar
for i, count in enumerate(yearly_funding['count']):
    ax1.text(yearly_funding.index[i], yearly_funding['mean'][i],
             f'n={count}', ha='center', va='bottom')

# 2. Growth metrics by market
market_metrics = data.groupby('Markets').agg({
    'Total Headcount': 'mean',
    '12 Month Headcount Change %': 'mean',
    'Mosaic (Overall)': 'mean'
}).sort_values('Total Headcount', ascending=False)

market_metrics.plot(kind='bar', ax=ax2)
ax2.set_title('Market Comparison: Headcount, Growth, and Mosaic Score', pad=20)
ax2.set_xlabel('Markets')
ax2.legend()
ax2.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# Detailed statistical analysis
print("\nMarket Statistics:")
market_stats = data.groupby('Markets').agg({
    'Total Funding (M)': ['mean', 'median', 'count'],
    'Total Headcount': ['mean', 'median'],
    '12 Month Headcount Change %': ['mean', 'median'],
    'Mosaic (Overall)': ['mean', 'median']
}).round(2)


print(market_stats)

# Create new figure for heatmap
plt.figure(figsize=(12, 6))
growth_analysis = pd.crosstab(
    pd.qcut(data['Founded Year'], q=4, labels=['Early', 'Growth', 'Mature', 'Established']),
    pd.qcut(data['Total Funding (M)'], q=4, labels=['Low', 'Medium', 'High', 'Very High'])
)

sns.heatmap(growth_analysis, annot=True, fmt='d', cmap='YlOrRd')
plt.title('Company Distribution: Age vs Funding')
plt.xlabel('Funding Level')
plt.ylabel('Company Age Stage')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# KeyError: 0.0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-cff8c556f63a> in <cell line: 12>()
#      11 # Add company count as text above each bar
# ...

# %%
# Calculate growth metrics
plt.figure(figsize=(12, 6))

# Create funding bins
data['Funding_Bin'] = pd.qcut(data['Total Funding (M)'],
                             q=5,
                             labels=['Very Low', 'Low', 'Medium', 'High', 'Very High'])

# Analyze headcount growth by funding level
growth_by_funding = data.groupby('Funding_Bin')['12 Month Headcount Change %'].agg(['mean', 'median', 'count'])

# Plot
ax = growth_by_funding[['mean', 'median']].plot(kind='bar',
                                               width=0.8,
                                               color=['skyblue', 'orange'])
plt.title('Headcount Growth by Funding Level')
plt.xlabel('Funding Level')
plt.ylabel('Headcount Growth %')

# Add company count annotations
for i, count in enumerate(growth_by_funding['count']):
    plt.text(i, plt.ylim()[0], f'n={count}', ha='center', va='top')

plt.legend(['Mean Growth', 'Median Growth'])
plt.tight_layout()
plt.show()
